# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
def scoring(path, filename):
    means, stds = [], []
    for metr in ["AUC-PR", "AUC-ROC", "Standard-F1"]:
        over_rows = []
        for seed in range(3,8,1):
            over = pd.read_csv(f"{path}_{seed}.csv")
            over = over[over["filename"].isin(file_list)]
            over_rows.append(over[metr])
        
        over_arr = np.stack(over_rows, axis=0)
        over_row_mean = over_arr.mean(axis=0)
        over_row_std  = over_arr.std(axis=0)
        
        over_global_mean = over_row_mean.mean()
        over_global_std  = over_row_std.mean()

        means.append(over_global_mean)
        stds.append(over_global_std)
        print(f"{metr}: {over_global_mean*100:.1f} ± {over_global_std*100:.1f}")
    return means, stds

# %%
file_list_path = 'Datasets/File_List/TSB-AD-U-Eva.csv'
file_list = pd.read_csv(file_list_path)['file_name'].values

# %%
_ = scoring("results/DLinear/eval_hp", file_list)
# Out:
# AUC-PR: 41.5 ± 0.5
# AUC-ROC: 80.7 ± 0.4
# Standard-F1: 45.7 ± 0.5

# %%
_ = scoring("results/PCA/auto_75", file_list)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 _ = scoring("results/PCA/auto_75", file_list)
#
# Cell In[2], line 10, in scoring(path, filename)
#       7     over = over[over["filename"].isin(file_list)]
#       8     over_rows.append(over[metr])
# ---> 10 over_arr = np.stack(over_rows, axis=0)
#      11 over_row_mean = over_arr.mean(axis=0)
#      12 over_row_std  = over_arr.std(axis=0)
#
# File ~/miniconda3/envs/TSB-AD/lib/python3.11/site-packages/numpy/core/shape_base.py:449, in stack(arrays, axis, out, dtype, casting)
#     447 shapes = {arr.shape for arr in arrays}
#     448 if len(shapes) != 1:
# --> 449     raise ValueError('all input arrays must have the same shape')
#     451 result_ndim = arrays[0].ndim + 1
#     452 axis = normalize_axis_index(axis, result_ndim)
#
# ValueError: all input arrays must have the same shape
